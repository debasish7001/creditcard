# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Loading Data set

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.size
# Out:
# 8829017

# %% [markdown]
# # Preproceding the Dataset

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(25,15))
corr=df.corr()
sns.heatmap(corr,annot=True,linewidths=1)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.countplot(df['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# This is anunbalanced Data set. So we have to balanced,here we used oversampling to balanced.

# %% [markdown]
# Balanced Dataset

# %%
from sklearn.utils import resample

# %%
majority=df[(df['Class']==0)]

# %%
mainority=df[(df['Class']==1)]

# %%
df1=resample(mainority,replace=True,n_samples=284315,random_state=42)

# %%
df2=pd.concat([df1,majority])

# %%
sns.countplot(df2['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %% [markdown]
# # Input Split

# %%
x = df2.drop(columns=['Class'], axis=1)
y = df2['Class']

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1= sc.fit_transform(x)

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x1,y,train_size=0.6)

# %% [markdown]
# # Logestic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='newton-cg')

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
lr.score(x_test,y_test)
# Out:
# 0.9497036737421521

# %%
#from sklearn.metrics import confusion_matrix
#confusion_matrix(lr.predict(x_test),y_test)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)
# Out:
# 0.999951638147829

# %% [markdown]
# # xgboost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
xgboost = GradientBoostingClassifier()

# %%
xgboost.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
xgboost.score(x_test,y_test)
# Out:
# 0.9984989861573168

# %% [markdown]
# # For imbalanced Dataset

# %%
x = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x2= sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x2,y,train_size=0.6)

# %% [markdown]
# Logestic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(solver='newton-cg')

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
from sklearn.metrics import classification_report, f1_score

# %%
y_pred = lr.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113755
#            1       0.83      0.65      0.73       168
#
#     accuracy                           1.00    113923
#    macro avg       0.92      0.82      0.86    113923
# weighted avg       1.00      1.00      1.00    113923
#
# F1 Score: 0.7290969899665553

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran=RandomForestClassifier()

# %%
ran.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = ran.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113755
#            1       0.94      0.79      0.86       168
#
#     accuracy                           1.00    113923
#    macro avg       0.97      0.90      0.93    113923
# weighted avg       1.00      1.00      1.00    113923
#
# F1 Score: 0.8580645161290321

# %% [markdown]
# XGBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
xg = GradientBoostingClassifier()

# %%
xg.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = lr.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113755
#            1       0.83      0.65      0.73       168
#
#     accuracy                           1.00    113923
#    macro avg       0.92      0.82      0.86    113923
# weighted avg       1.00      1.00      1.00    113923
#
# F1 Score: 0.7290969899665553
